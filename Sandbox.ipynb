# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime, timedelta

# %%
data = pd.read_csv('1996-2019.csv', index_col=['date'], parse_dates=['date'])
data.head()
# Out:
#             Acer  Aesculus  Alnus  Ambrosia  Artemisia  Asteraceae  Betula  \
# date
# 1996-01-07     0         0      0         0          0           0       0
# 1996-01-08     0         0      0         0          0           0       0
# 1996-01-09     0         0      0         0          0           0       0
# 1996-01-10     0         0      0         0          0           0       0
# 1996-01-11     0         0      0         0          0           0       0
#
#             Carpinus  Castanea  Chenopodium  ...  Platanus  Populus  Quercus  \
# date                                         ...
# 1996-01-07         0         0            0  ...         0        0        0
# 1996-01-08         0         0            0  ...         0        0        0
# 1996-01-09         0         0            0  ...         0        0        0
# 1996-01-10         0         0            0  ...         0        0        0
# 1996-01-11         0         0            0  ...         0        0        0
#
#             Rumex  Salix  Sambucus  Tilia  Ulmus  Umbellifereae  Urtica
# date
# 1996-01-07      0      0         0      0      0              0       0
# 1996-01-08      0      0         0      0      0              0       0
# 1996-01-09      0      0         0      0      0              0       0
# 1996-01-10      0      0         0      0      0              0       0
# 1996-01-11      0      0         0      0      0              0       0
#
# [5 rows x 33 columns]

# %%
data.columns
# Out:
# Index(['Acer', 'Aesculus', 'Alnus', 'Ambrosia', 'Artemisia', 'Asteraceae',
#        'Betula', 'Carpinus', 'Castanea', 'Chenopodium', 'Corylus',
#        'Cupressaceae', 'Cyperaceae', 'Ericaceae', 'Fagus', 'Filipendula',
#        'Fraxinus', 'Gramineae', 'Juglans', 'Juncaceae', 'Larix', 'Pinaceae',
#        'Plantago', 'Platanus', 'Populus', 'Quercus', 'Rumex', 'Salix',
#        'Sambucus', 'Tilia', 'Ulmus', 'Umbellifereae', 'Urtica'],
#       dtype='object')

# %%
data = data.loc[
    (data.index >= (datetime.now() - timedelta(days=90))) &
    (data.index <= datetime.now())
]
sns.lineplot(x=data.index, y='Gramineae', data=data)
